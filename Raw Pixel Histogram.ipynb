# %%
import ipystata  
import pandas as pd
import savReaderWriter as s
import numpy as np
import time
import os
import os.path
from osgeo import gdal, ogr, osr
from scipy import ndimage
from scipy import misc
from io import StringIO
#import cStringIO
gdal.UseExceptions()
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline
import urllib
import seaborn as sns

# %%
rwanda = pd.read_csv('D:/Intensive Data/Final Project/Nightlights for TL/rwanda_TL.csv')
haiti = pd.read_csv('D:/Intensive Data/Final Project/Nightlights for TL/haiti_TL.csv')
nepal = pd.read_csv('D:/Intensive Data/Final Project/Nightlights for TL/nepal_TL.csv')
bangladesh = pd.read_csv('D:/Intensive Data/Final Project/Nightlights for TL/bangladesh_TL.csv')
burundi = pd.read_csv('D:/Intensive Data/Final Project/Nightlights for TL/burundi_TL.csv')
honduras = pd.read_csv('D:/Intensive Data/Final Project/Nightlights for TL/honduras_TL.csv')
guatemala = pd.read_csv('D:/Intensive Data/Final Project/Nightlights for TL/guatemala_TL.csv')

# %%
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))

# %%
country = [rwanda]
country_str = ['rwanda']


plot1 = sns.distplot(rwanda['lightness'],kde=False);
plot1.set(xlabel='Luminosity', ylabel='# of pixels', title = 'Rwanda')

# %%
plot1 = sns.distplot(rwanda['lightness'],kde=False);
plot1.set(xlabel='pixels', ylabel='%s_clusters', title = 'Rwanda')

# %%
plot1 = sns.distplot(haiti['lightness'],kde=False);
plot1.set(xlabel='pixels', ylabel='%s_clusters', title = 'Haiti')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-b21cbbae1897> in <module>()
# ----> 1 index(country)
#
# NameError: name 'index' is not defined
